% %% [markdown]
% # Nailing down this 'blooming' event

% %% [markdown]
% for the seven6 knot, it looks like the event occurs between T=2950 and T=3200. Lets try and get some solid ideas of what is going on here
